# %%
# Import & Visualize data
import pandas
import numpy as np
import matplotlib.pyplot as plt

file_name = 'Real estate.csv'
real_estate_df = pandas.read_csv(file_name)
real_estate_df.shape
real_estate_df
real_estate_df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
# Treat & prepare data
## Drop 'No' column
real_estate_df = real_estate_df.drop('No', axis=1)
# Out:
# '"\ndataset = pandas.read_csv(file_name)\ndis_nearest_mrt = dataset[\'X3 distance to the nearest MRT station\']\ny = dataset[\'Y house price of unit area\']\nhouse_age = dataset[\'X2 house age\']\nfig, ax = plt.subplots(1,1)\nax.set_ylabel(\'Y house price of unit area\')\nax.set_xlabel(\'distance to the nearest MRT station\')\nax.scatter(dis_nearest_mrt, y)\n'

# %%
# Get train and test data
# 80% of dataset will be for train and the rest for test
train_set_ratio = 0.8*real_estate_df.shape[0]
train_set = real_estate_df.loc[:train_set_ratio-1, :]
test_set = real_estate_df.loc[train_set_ratio:, :]
train_set
test_set
# Out:
#      X1 transaction date  X2 house age  \
# 332             2013.167          39.8
# 333             2012.750           7.8
# 334             2012.917          30.0
# 335             2013.583          27.3
# 336             2012.833           5.1
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 332                               617.71340                                2
# 333                               104.81010                                5
# 334                              1013.34100                                5
# 335                               337.60160                                6
# 336                              1867.23300                                2
# ...

# %%
# Get feateares & target for train and test sets
feature_column_name =  'Y house price of unit area'
y_train = train_set[feature_column_name].values
X_train = train_set.drop(feature_column_name, axis=1).values
y_test = test_set[feature_column_name].values
X_test = test_set.drop(feature_column_name, axis=1).values
# Out:
# array([ 37.9,  42.2,  47.3,  54.8,  43.1,  32.1,  40.3,  46.7,  18.8,
#         22.1,  41.4,  58.1,  39.3,  23.8,  34.3,  50.5,  70.1,  37.4,
#         42.3,  47.7,  29.3,  51.6,  24.6,  47.9,  38.8,  27. ,  56.2,
#         33.6,  47. ,  57.1,  22.1,  25. ,  34.2,  49.3,  55.1,  27.3,
#         22.9,  25.3,  47.7,  46.2,  15.9,  18.2,  34.7,  34.1,  53.9,
#         38.3,  42. ,  61.5,  13.4,  13.2,  44.2,  20.7,  27. ,  38.9,
#         51.7,  13.7,  41.9,  53.5,  22.6,  42.4,  21.3,  63.2,  27.7,
#         55. ,  25.3,  44.3,  50.7,  56.8,  36.2,  42. ,  59. ,  40.8,
#         36.3,  20. ,  54.4,  29.5,  36.8,  25.6,  29.8,  26.5,  40.3,
#         36.8,  48.1,  17.7,  43.7,  50.8,  27. ,  18.3,  48. ,  25.3,
#         45.4,  43.2,  21.8,  16.1,  41. ,  51.8,  59.5,  34.6,  51. ,
#         62.2,  38.2,  32.9,  54.4,  45.7,  30.5,  71. ,  47.1,  26.6,
#         34.1,  28.4,  51.6,  39.4,  23.1,   7.6,  53.3,  46.4,  12.2,
# ...

# %%
# split dataset into test and train datasets
# 80 percentis will be for train and rest is for test
eighty_pct = 0.8*dataset.shape[0]
#X = dataset.drop('Y house price of unit area', axis=1)
train = dataset.loc[:eighty_pct-1, :]
test_set = dataset.loc[eighty_pct:, :]
y_train = train['Y house price of unit area'].values
X_train = train.drop('Y house price of unit area', axis=1).values
X_train.shape


def compute_squared_errors_cost(X, y, w, b):
    
    cost = 0.0
    m = X.shape[0]
    
    for i in range(m):
        f_wb = np.dot(X[i], w) + b
        cost += (f_wb - y[i])**2
    cost = cost / (1/(2*m))
    return cost
w = [3, 5, 2, 1, 4, 2, 1]

test_c = compute_squared_errors_cost(X_train, y_train, w, 1)

def compute_gradient_lg(X, y, w, b):
    m, n = X.shape
    dj_dw = np.zeros((n,))
    dj_db = 0.0
    print('X', X[3, 3])
    for i in range(m):
        f_wb_i = np.dot(X[i], b)
        error = f_wb_i - y[i]
        for j in range(n):
            print(i,j)
            dj_dw[j] += dj_dw[j] + error * X[i,j]
        dj_db += dj_db + error
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    
    return dj_dw, dj_db

def find_best_parameter(X, y, alpha, iters, w, b):
    m,n = X.shape
    for i in range(m):
        dj_dw, dj_db = compute_gradient_lg(X, y, w, b)
        b = b - alpha * dj_db
        for j in (n):
            w[j] = w[j] - alpha * dj_dw
    
    return {"final_w": w, "final_b": b}
            
w_guess = [3, 10, 23, 7, 2, 13, 4]
finalwtf = find_best_parameter(X_train, y_train, 0.1, 100, w_guess, 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 3
#       1 # split dataset into test and train datasets
#       2 # 80 percentis will be for train and rest is for test
# ----> 3 eighty_pct = 0.8*dataset.shape[0]
#       4 #X = dataset.drop('Y house price of unit area', axis=1)
#       5 train = dataset.loc[:eighty_pct-1, :]
#
# NameError: name 'dataset' is not defined
